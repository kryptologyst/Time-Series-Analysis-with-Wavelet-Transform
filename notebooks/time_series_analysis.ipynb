# %% [markdown]
# # Time Series Analysis with Wavelet Transform
#
# This notebook demonstrates comprehensive time series analysis using wavelet transforms, forecasting, and anomaly detection.
#
# ## Overview
#
# We'll explore:
# 1. **Data Generation**: Creating realistic synthetic time series
# 2. **Wavelet Analysis**: Time-frequency analysis using CWT and DWT
# 3. **Forecasting**: Multiple forecasting models (ARIMA, Prophet, LSTM)
# 4. **Anomaly Detection**: Statistical and ML-based anomaly detection
# 5. **Visualization**: Interactive plots and comprehensive dashboards
